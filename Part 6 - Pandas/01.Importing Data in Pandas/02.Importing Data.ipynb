# %% [markdown]
# # Importing Data Using Pandas
#
# ## Introduction
#
# Pandas is a popular library for efficiently wrangling data. Pandas is particularly optimized to work with two-dimensional tabular data that is organized in rows and columns. In this lesson, you will learn how to import tabular data as a Pandas DataFrame object, how to access and manipulate the data in DataFrame objects, and how to export DataFrames to some common file formats.
#
# For more information on Pandas, refer to https://pandas.pydata.org/pandas-docs/stable/ .
#
# ## Objectives
# You will be able to:
# - Import data from csv files and Excel files
# - Understand and explain key arguments for imports
# - Save information to csv and Excel files
# - Access data within a Pandas DataFrame (print() and .head())
#
# ## Loading Pandas
# ![pleasedont](https://media.giphy.com/media/5zjdLoaVHKHuhQdtRF/giphy.gif)
#
# When importing Pandas, it is standard to import it under the alias `pd`

# %%
import pandas as pd  # pd is an alias

# %% [markdown]
# ## Importing Data
#
# There are a few main functions for importing data into a Pandas DataFrame including:
#
# * `pd.read_csv()`
# * `pd.read_excel()`
# * `pd.read_json()`
# * `pd.DataFrame.from_dict()`
#
# Most of these methods are fairly straightforward; you use `read_csv()` for csv files, `read_excel()` for excel files (both new and old `.xlx` and `.xlsx` formats), and `read_json()` for json files. That said, there are a few nuances you should know about. The first is that the `read_csv()` format can be used for any plain-text delimited file. This may include (but is not limited to) pipe (|) delimited files (`.psv`) and tab separated files (`.tsv`).
#
# Let's look at an example by investigating a file, `'bp.txt'`, stored in the `Data` folder.

# %%
data = pd.read_csv("../data/bp.txt")
data.head()
# Out:
#   Pt\tBP\tAge\tWeight\tBSA\tDur\tPulse\tStress
# 0          1\t105\t47\t85.4\t1.75\t5.1\t63\t33
# 1          2\t115\t49\t94.2\t2.10\t3.8\t70\t14
# 2          3\t116\t49\t95.3\t1.98\t8.2\t72\t10
# 3          4\t117\t50\t94.7\t2.01\t5.8\t73\t99
# 4          5\t112\t51\t89.4\t1.89\t7.0\t72\t95

# %%
data = pd.read_csv("../data/bp.txt" , delimiter="\t")
data.head()
# Out:
#    Pt   BP  Age  Weight   BSA  Dur  Pulse  Stress
# 0   1  105   47    85.4  1.75  5.1     63      33
# 1   2  115   49    94.2  2.10  3.8     70      14
# 2   3  116   49    95.3  1.98  8.2     72      10
# 3   4  117   50    94.7  2.01  5.8     73      99
# 4   5  112   51    89.4  1.89  7.0     72      95

# %% [markdown]
# + We've now loaded the data from a file into a DataFrame. To investigate the DataFrame, we can use a method called `.head(n)` or `.tail(n)`, which will respectively return first and last __n__ items in the DataFrame.

# %%
data.head(3)
# Out:
#    Pt   BP  Age  Weight   BSA  Dur  Pulse  Stress
# 0   1  105   47    85.4  1.75  5.1     63      33
# 1   2  115   49    94.2  2.10  3.8     70      14
# 2   3  116   49    95.3  1.98  8.2     72      10

# %%
data.tail(2)
# Out:
#     Pt   BP  Age  Weight   BSA  Dur  Pulse  Stress
# 18  19  110   48    90.5  1.88  9.0     71      99
# 19  20  122   56    95.7  2.09  7.0     75      99

# %% [markdown]
# This example shows that the data was tab delimited (`\t`), so an appropriate file extension could have also been `.tsv`. Once we've loaded the dataset, we can export it to any format we would like with the related methods:
#
# * `df.to_csv()`
# * `df.to_excel()`
# * `df.to_json()`
# * `df.to_dict()`
#
# There are also several other options available, but these are the most common.
#
# ## Skipping and Limiting Rows
#
# Another feature that you may have to employ is skipping rows when there is metadata stored at the top of a file. You can do this using the optional parameter `skiprows`. Similarly, if you want to only load a portion of a large file as an initial preview, you can use the `nrows` parameter.

# %%
df = pd.read_csv("../data/ACS_16_5YR_B24011_with_ann.csv" , nrows=100)
df.head()
# Out:
#            GEO.id GEO.id2        GEO.display-label         HD01_VD01  \
# 0              Id     Id2                Geography  Estimate; Total:
# 1  0500000US01001   01001  Autauga County, Alabama             33267
# 2  0500000US01003   01003  Baldwin County, Alabama             31540
# 3  0500000US01005   01005  Barbour County, Alabama             26575
# 4  0500000US01007   01007     Bibb County, Alabama             30088
#
#                  HD02_VD01                                          HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Management, business, scien...
# 1                     2306                                              48819
# 2                      683                                              49524
# 3                     1653                                              41652
# 4                     2224                                              40787
#
#                                            HD02_VD02  \
# 0  Margin of Error; Total: - Management, business...
# 1                                               1806
# 2                                               1811
# 3                                               2638
# 4                                               2896
#
#                                            HD01_VD03  \
# 0  Estimate; Total: - Management, business, scien...
# 1                                              55557
# 2                                              57150
# 3                                              51797
# 4                                              50069
#
#                                            HD02_VD03  \
# 0  Margin of Error; Total: - Management, business...
# 1                                               4972
# 2                                               6980
# 3                                               5980
# 4                                              12841
#
#                                            HD01_VD04  ...  \
# 0  Estimate; Total: - Management, business, scien...  ...
# 1                                              63333  ...
# 2                                              63422  ...
# 3                                              52775  ...
# 4                                              67917  ...
#
#                                            HD01_VD32  \
# 0  Estimate; Total: - Natural resources, construc...
# 1                                              31402
# 2                                              35603
# 3                                              37847
# 4                                              45952
#
#                                            HD02_VD32  \
# 0  Margin of Error; Total: - Natural resources, c...
# 1                                               5135
# 2                                               3882
# 3                                              11189
# 4                                               5622
#
#                                            HD01_VD33  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              35594
# 2                                              30549
# 3                                              26094
# 4                                              28983
#
#                                            HD02_VD33  \
# 0  Margin of Error; Total: - Production, transpor...
# 1                                               3034
# 2                                               1606
# 3                                               4884
# 4                                               3401
#
#                                            HD01_VD34  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              36059
# 2                                              29604
# 3                                              25339
# 4                                              31881
#
#                                            HD02_VD34  \
# 0  Margin of Error; Total: - Production, transpor...
# 1                                               3893
# 2                                               4554
# 3                                               4900
# 4                                               2317
#
#                                            HD01_VD35  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              47266
# 2                                              35504
# 3                                              37282
# 4                                              26580
#
#                                            HD02_VD35  \
# 0  Margin of Error; Total: - Production, transpor...
# 1                                              13608
# 2                                               6260
# 3                                               6017
# 4                                               2901
#
#                                            HD01_VD36  \
# 0  Estimate; Total: - Production, transportation,...
# 1                                              19076
# 2                                              24182
# 3                                              16607
# 4                                              23479
#
#                                            HD02_VD36
# 0  Margin of Error; Total: - Production, transpor...
# 1                                               4808
# 2                                               3580
# 3                                               3497
# 4                                               4942
#
# [5 rows x 75 columns]

# %% [markdown]
# ### Notice the first row is descriptions of the variables

# %% [markdown]
# + We can drop them manually

# %%
df = df.drop(0)
df.head(3)
# Out:
#            GEO.id GEO.id2        GEO.display-label HD01_VD01 HD02_VD01  \
# 1  0500000US01001   01001  Autauga County, Alabama     33267      2306
# 2  0500000US01003   01003  Baldwin County, Alabama     31540       683
# 3  0500000US01005   01005  Barbour County, Alabama     26575      1653
#
#   HD01_VD02 HD02_VD02 HD01_VD03 HD02_VD03 HD01_VD04  ... HD01_VD32 HD02_VD32  \
# 1     48819      1806     55557      4972     63333  ...     31402      5135
# 2     49524      1811     57150      6980     63422  ...     35603      3882
# 3     41652      2638     51797      5980     52775  ...     37847     11189
#
#   HD01_VD33 HD02_VD33 HD01_VD34 HD02_VD34 HD01_VD35 HD02_VD35 HD01_VD36  \
# 1     35594      3034     36059      3893     47266     13608     19076
# 2     30549      1606     29604      4554     35504      6260     24182
# 3     26094      4884     25339      4900     37282      6017     16607
#
#   HD02_VD36
# 1      4808
# 2      3580
# 3      3497
#
# [3 rows x 75 columns]

# %% [markdown]
# ## Header
#
# Related to `skiprows` is the `header` parameter. This specifies the row where column names are and starts importing data from that point:

# %%
# look at the error output once you run this cell. What type of error is it?
df = pd.read_csv('../data/ACS_16_5YR_B24011_with_ann.csv', header=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-9ed1f2cc1144> in <module>
#       1 # look at the error output once you run this cell. What type of error is it?
# ----> 2 df = pd.read_csv('../data/ACS_16_5YR_B24011_with_ann.csv', header=1)
#       3 df.head()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte

# %% [markdown]
# ## Encoding
#
# Encoding errors like the one above are always frustrating. This has to do with how the strings within the file itself are formatted. The most common encoding other than `utf-8` that you are likely to come across is `latin-1`.

# %%
df = pd.read_csv("../data/ACS_16_5YR_B24011_with_ann.csv" , header=1 , encoding="latin-1")
df.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama             33267
# 1  0500000US01003  1003  Baldwin County, Alabama             31540
# 2  0500000US01005  1005  Barbour County, Alabama             26575
# 3  0500000US01007  1007     Bibb County, Alabama             30088
# 4  0500000US01009  1009   Blount County, Alabama             34900
#
#    Margin of Error; Total:  \
# 0                     2306
# 1                      683
# 2                     1653
# 3                     2224
# 4                     2063
#
#    Estimate; Total: - Management, business, science, and arts occupations:  \
# 0                                              48819
# 1                                              49524
# 2                                              41652
# 3                                              40787
# 4                                              46593
#
#    Margin of Error; Total: - Management, business, science, and arts occupations:  \
# 0                                               1806
# 1                                               1811
# 2                                               2638
# 3                                               2896
# 4                                               2963
#
#    Estimate; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations:  \
# 0                                              55557
# 1                                              57150
# 2                                              51797
# 3                                              50069
# 4                                              47003
#
#    Margin of Error; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations:  \
# 0                                               4972
# 1                                               6980
# 2                                               5980
# 3                                              12841
# 4                                               6189
#
#   Estimate; Total: - Management, business, science, and arts occupations: - Management, business, and financial occupations: - Management occupations  \
# 0                                              63333
# 1                                              63422
# 2                                              52775
# 3                                              67917
# 4                                              50991
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Estimate; Total: - Natural resources, construction, and maintenance occupations: - Installation, maintenance, and repair occupations  \
# 0                                              31402
# 1                                              35603
# 2                                              37847
# 3                                              45952
# 4                                              42489
#
#   Margin of Error; Total: - Natural resources, construction, and maintenance occupations: - Installation, maintenance, and repair occupations  \
# 0                                               5135
# 1                                               3882
# 2                                              11189
# 3                                               5622
# 4                                               7176
#
#   Estimate; Total: - Production, transportation, and material moving occupations:  \
# 0                                              35594
# 1                                              30549
# 2                                              26094
# 3                                              28983
# 4                                              32969
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations:  \
# 0                                               3034
# 1                                               1606
# 2                                               4884
# 3                                               3401
# 4                                               3767
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Production occupations  \
# 0                                              36059
# 1                                              29604
# 2                                              25339
# 3                                              31881
# 4                                              31814
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Production occupations  \
# 0                                               3893
# 1                                               4554
# 2                                               4900
# 3                                               2317
# 4                                               4551
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Transportation occupations  \
# 0                                              47266
# 1                                              35504
# 2                                              37282
# 3                                              26580
# 4                                              41375
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Transportation occupations  \
# 0                                              13608
# 1                                               6260
# 2                                               6017
# 3                                               2901
# 4                                               5280
#
#   Estimate; Total: - Production, transportation, and material moving occupations: - Material moving occupations  \
# 0                                              19076
# 1                                              24182
# 2                                              16607
# 3                                              23479
# 4                                              26755
#
#   Margin of Error; Total: - Production, transportation, and material moving occupations: - Material moving occupations
# 0                                               4808
# 1                                               3580
# 2                                               3497
# 3                                               4942
# 4                                               2963
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Selecting Specific Columns
#
# + You can also select specific columns if you only want to load specific features.

# %%
df = pd.read_csv('../data/ACS_16_5YR_B24011_with_ann.csv', usecols=[0,1,2,5,6], encoding='latin-1')
df.head(2)
# Out:
#            GEO.id GEO.id2        GEO.display-label  \
# 0              Id     Id2                Geography
# 1  0500000US01001   01001  Autauga County, Alabama
#
#                                            HD01_VD02  \
# 0  Estimate; Total: - Management, business, scien...
# 1                                              48819
#
#                                            HD02_VD02
# 0  Margin of Error; Total: - Management, business...
# 1                                               1806

# %% [markdown]
# # Or we can simply state

# %%
df = pd.read_csv('../data/ACS_16_5YR_B24011_with_ann.csv',
                 usecols=["GEO.id","GEO.id2","GEO.display-label"], encoding='latin-1')
df.head(2)
# Out:
#            GEO.id GEO.id2        GEO.display-label
# 0              Id     Id2                Geography
# 1  0500000US01001   01001  Autauga County, Alabama

# %% [markdown]
# ## Selecting Specific Sheets
# + You can also select specific sheets for Excel files! This can be done by index number.

# %%
df_new = pd.read_excel("../data/Yelp_Selected_Businesses.xlsx")
df_new.head()
# Out:
#                Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                     NaN        NaN         NaN        NaN
# 1             business_id       cool        date      funny
# 2  RESDUcs7fIiihp38-d6_6g          0  2015-09-16          0
# 3  RESDUcs7fIiihp38-d6_6g          0  2017-09-09          0
# 4  RESDUcs7fIiihp38-d6_6g          0  2013-01-14          0
#
#                Unnamed: 4 Unnamed: 5  \
# 0                     NaN        NaN
# 1               review_id      stars
# 2  gkcPdbblTvZDMSwx8nVEKw          5
# 3  mQfl6ci46mu0xaZrkRUhlA          5
# 4  EJ7DJ8bm7-2PLFB9WKx4LQ          3
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                                NaN        NaN
# 1                                               text     useful
# 2  Got here early on football Sunday 7:30am as I ...          0
# 3  This buffet is amazing.  Yes, it is expensive,...          0
# 4  I was really looking forward to this but it wa...          0
#
#                Unnamed: 8
# 0                     NaN
# 1                 user_id
# 2  SKteB5rgDlkkUa1Zxe1N0Q
# 3  f638AHA_GoHbyDB7VFMz7A
# 4  -wVPuTiIEG85LwTK46Prpw

# %% [markdown]
# # Skipping the header

# %%
df_new = pd.read_excel("../data/Yelp_Selected_Businesses.xlsx" , header=2)
df_new.head()
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  RESDUcs7fIiihp38-d6_6g     0  2015-09-16      0  gkcPdbblTvZDMSwx8nVEKw
# 1  RESDUcs7fIiihp38-d6_6g     0  2017-09-09      0  mQfl6ci46mu0xaZrkRUhlA
# 2  RESDUcs7fIiihp38-d6_6g     0  2013-01-14      0  EJ7DJ8bm7-2PLFB9WKx4LQ
# 3  RESDUcs7fIiihp38-d6_6g     0  2017-02-08      0  lMarDJDg4-e_0YoJOKJoWA
# 4  RESDUcs7fIiihp38-d6_6g     0  2012-11-19      0  nq_-8lZPUVGomDEP5OOj1Q
#
#    stars                                               text  useful  \
# 0      5  Got here early on football Sunday 7:30am as I ...       0
# 1      5  This buffet is amazing.  Yes, it is expensive,...       0
# 2      3  I was really looking forward to this but it wa...       0
# 3      2  This place....lol our server was nice.  But fo...       0
# 4      1  After hearing all the buzz about this place, I...       2
#
#                   user_id
# 0  SKteB5rgDlkkUa1Zxe1N0Q
# 1  f638AHA_GoHbyDB7VFMz7A
# 2  -wVPuTiIEG85LwTK46Prpw
# 3  A21zMqdN76ueLZFpmbue0Q
# 4  Jf1EXieUV7F7s-HGA4EsdA

# %% [markdown]
# # Or

# %%
df_new2 = pd.read_excel("../data/Yelp_Selected_Businesses.xlsx" ,sheet_name=2, header=2)
df_new2.head()
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  YJ8ljUhLsz6CtT_2ORNFmg     1  2013-04-25      0  xgUz0Ck4_ciNaeIk-H8GBQ
# 1  YJ8ljUhLsz6CtT_2ORNFmg     0  2014-07-07      0  Au7MG4QlAxqq9meyKSQmaw
# 2  YJ8ljUhLsz6CtT_2ORNFmg     0  2015-12-04      0  8IQnZ54nenXjlK-FGZ82Bg
# 3  YJ8ljUhLsz6CtT_2ORNFmg     2  2016-07-06      1  XY42LMhKoXzwtLoku4mvLA
# 4  YJ8ljUhLsz6CtT_2ORNFmg     0  2014-04-15      0  1xlYVWhyLedoA0HddOJMOw
#
#    stars                                               text  useful  \
# 0      5  I loved this place. Easily the most hipsters p...       1
# 1      5  So my boyfriend and I came here for my birthda...       0
# 2      5  I really enjoyed their food. Went there for th...       1
# 3      5  A complete Vegas experience. We arrived right ...       3
# 4      4  Very great atmosphere had a wonderful bartende...       0
#
#                   user_id
# 0  6cpo8iqgnW3jnozhmY7eAA
# 1  8bFE3u1dMoYXkS7ORqlssw
# 2  bJmE1ms0MyZ6KHjmfZDWGw
# 3  PbccpC-I-8rxzF2bCDh8YA
# 4  yvlRColhqo_4TzpUFKyroA

# %% [markdown]
# ### Or the name of the sheet itself : 'Biz_id_RESDU'

# %%
df = pd.read_excel('../data/Yelp_Selected_Businesses.xlsx', sheet_name='Biz_id_RESDU', header=2)
df.head(3)
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  RESDUcs7fIiihp38-d6_6g     0  2015-09-16      0  gkcPdbblTvZDMSwx8nVEKw
# 1  RESDUcs7fIiihp38-d6_6g     0  2017-09-09      0  mQfl6ci46mu0xaZrkRUhlA
# 2  RESDUcs7fIiihp38-d6_6g     0  2013-01-14      0  EJ7DJ8bm7-2PLFB9WKx4LQ
#
#    stars                                               text  useful  \
# 0      5  Got here early on football Sunday 7:30am as I ...       0
# 1      5  This buffet is amazing.  Yes, it is expensive,...       0
# 2      3  I was really looking forward to this but it wa...       0
#
#                   user_id
# 0  SKteB5rgDlkkUa1Zxe1N0Q
# 1  f638AHA_GoHbyDB7VFMz7A
# 2  -wVPuTiIEG85LwTK46Prpw

# %% [markdown]
# ## Loading a Full Workbook and Previewing Sheet Names
# + You can also load an entire excel workbook (which is a collection of spreadsheets) with the `pd.ExcelFile()` function.

# %%
excelbooks = pd.ExcelFile("../data/Yelp_Selected_Businesses.xlsx")
excelbooks.sheet_names
# Out:
# ['Biz_id_RESDU',
#  'Biz_id_4JNXU',
#  'Biz_id_YJ8lj',
#  'Biz_id_ujHia',
#  'Biz_id_na4Th']

# %%
df_excel = excelbooks.parse(sheet_name=1, header=2)
df_excel.head(3)
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  4JNXUYY8wbaaDmk3BPzlWw     0  2012-06-10      0  wl8BO_I-is-JaMwMW5c_gQ
# 1  4JNXUYY8wbaaDmk3BPzlWw     0  2012-01-20      0  cf9RrqHY9eQ9M53OPyXLtg
# 2  4JNXUYY8wbaaDmk3BPzlWw     0  2017-05-10      0  BvmhSQ6WFm2Jxu01G8OpdQ
#
#    stars                                               text  useful  \
# 0      4  I booked a table here for brunch and it did no...       0
# 1      4  Came here for lunch after a long night of part...       0
# 2      5  Loved the fried goat cheese in tomato sauce al...       0
#
#                   user_id
# 0  fo4mpUqgXL2mJqALc9AvbA
# 1  TVvTtXwPXsvrg2KJGoOUTg
# 2  etbAVunw-4kwr6VTRweZpA

# %% [markdown]
# ## Saving Data
# Once we have data loaded that we may want to export back out, we use the **`.to_csv()`** or **`.to_excel()`** methods of any DataFrame object.

# %% [markdown]
# + Notice how we have to pass index=False if we do not want it included in our output

# %%
df.to_csv('../data/NewSavedView.csv', index=False)

# %% [markdown]
# # <a id='7'>Saving File To CSV as a compression file</a>

# %%
compression_opts = dict(method='zip',
                        archive_name='Cleaned.csv')  
df.to_csv('Cleaned.zip', index=False,
          compression=compression_opts)

# %% [markdown]
# # Importing messy data

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. __Import__ the csv-file __cars_raw.csv__ with the appropriate pandas method and __inspect__ the data!
#
# 2. __Remove__ the __first row(s)__ containing nonsense content.
#
# 3. __Remove__ the __last row(s)__ containing nonsense content.
#
# 4. Define that there are __no appropriate column labels/headers__ in the data.
#
# 5. __Set__ the following __column labels/headers__:
#
# **labels = ['mpg','cylinders','displacement','horsepower','weight', 'acceleration'
#           'model',  'year','origin','name']**

# %%
pd.read_csv("../data/cars_raw.csv")
# Out:
#                                           Welcome    to            the  \
# Feel    free  to         analyze  and       clean   the          messy
# 18.0   8     307.0      130.0 hp 3504        12.0    70  United States
# 15.0   8     350.0      165.0 hp 3693        11.5    70  United States
# 18.0   8     318.0      150.0 hp 3436        11.0    70  United States
# 16.0   8     304.0      150.0 hp 3433        12.0    70            usa
# ...                                           ...   ...            ...
# 27.0   4     101.0      83.0 hp  2202        15.3    76         europe
# 17.0   6     250.0      100.0 hp 3329        15.5    71            usa
# 14.5   8     351.0      152.0 hp 4215        12.8    76            usa
# 25.0   6     181.0      110.0 hp 2945        16.4    82            usa
# Thanks  for   analyzing  this     Dataset       !   NaN            NaN
#
#                                                                    cars  \
# Feel    free  to         analyze  and                           Dataset
# 18.0   8     307.0      130.0 hp 3504        chevrolet chevelle malibu
# 15.0   8     350.0      165.0 hp 3693                buick skylark 320
# 18.0   8     318.0      150.0 hp 3436               plymouth satellite
# 16.0   8     304.0      150.0 hp 3433                    amc rebel sst
# ...                                                                 ...
# 27.0   4     101.0      83.0 hp  2202                     renault 12tl
# 17.0   6     250.0      100.0 hp 3329        chevrolet chevelle malibu
# 14.5   8     351.0      152.0 hp 4215                 ford gran torino
# 25.0   6     181.0      110.0 hp 2945            buick century limited
# Thanks  for   analyzing  this     Dataset                           NaN
#
#                                            Dataset!
# Feel    free  to         analyze  and             !
# 18.0   8     307.0      130.0 hp 3504           NaN
# 15.0   8     350.0      165.0 hp 3693           NaN
# 18.0   8     318.0      150.0 hp 3436           NaN
# 16.0   8     304.0      150.0 hp 3433           NaN
# ...                                             ...
# 27.0   4     101.0      83.0 hp  2202           NaN
# 17.0   6     250.0      100.0 hp 3329           NaN
# 14.5   8     351.0      152.0 hp 4215           NaN
# 25.0   6     181.0      110.0 hp 2945           NaN
# Thanks  for   analyzing  this     Dataset       NaN
#
# [331 rows x 5 columns]

# %% [markdown]
# 2. Use appropriate __parameters__ in the __pd.read_csv()__ method to clean the format. The following issues need to be solved: # create the column names and attache it to the dataframe

# %%
columns = ['mpg',"cylinders","dsiplacement","horsepower","weight","acceleration",
           "model year", "origin", "name"]

# %%
pd.read_csv("../data/cars_raw.csv",skiprows=2, skipfooter=1, header=None, names=columns)
# Out:
#       mpg  cylinders  dsiplacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0   130.0 hp    3504          12.0
# 1    15.0          8         350.0   165.0 hp    3693          11.5
# 2    18.0          8         318.0   150.0 hp    3436          11.0
# 3    16.0          8         304.0   150.0 hp    3433          12.0
# 4    17.0          8         302.0   140.0 hp    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year         origin                          name
# 0            70  United States    chevrolet chevelle malibu
# 1            70  United States            buick skylark 320
# 2            70  United States           plymouth satellite
# 3            70            usa                amc rebel sst
# 4            70            usa                  FORD TORINO
# ..          ...            ...                           ...
# 324          73            usa     mercury marquis brougham
# 325          76         europe                 renault 12tl
# 326          71            usa    chevrolet chevelle malibu
# 327          76            usa             ford gran torino
# 328          82            usa        buick century limited
#
# [329 rows x 9 columns]

# %%
Car_data= pd.read_csv("../data/cars_raw.csv",skiprows=2, skipfooter=1, 
                      header=None, names=columns)
Car_data.head(4)
# Out:
#     mpg  cylinders  dsiplacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
# 2  18.0          8         318.0   150.0 hp    3436          11.0          70
# 3  16.0          8         304.0   150.0 hp    3433          12.0          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320
# 2  United States           plymouth satellite
# 3            usa                amc rebel sst

# %%
Car_data.tail(4)
# Out:
#       mpg  cylinders  dsiplacement horsepower  weight  acceleration  \
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year  origin                          name
# 325          76  europe                 renault 12tl
# 326          71     usa    chevrolet chevelle malibu
# 327          76     usa             ford gran torino
# 328          82     usa        buick century limited

# %%
Car_data["origin"].plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-8e1d46c3b15c> in <module>
# ----> 1 Car_data["origin"].plot(kind="bar")
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
Car_data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# dsiplacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# 6. __Export__ and __save__ cars as new csv-file (__cars_imp.csv__). Do __not__ export any __RangeIndex__!

# %%
Car_data.to_csv("../data/cars_import.csv", index= False)

# %% [markdown]
# # Summary
#
# + Great job
# + In the session we got introduced to the world of Pandas.

# %% [markdown]
# ![dance](https://media.giphy.com/media/gLbpuugfk2nILFepeI/giphy.gif)
